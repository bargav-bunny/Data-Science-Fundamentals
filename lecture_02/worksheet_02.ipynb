# %% [markdown]
# # Worksheet 02
#
# Name: Bargav Jagatha
# <br>
# UID: U80005052
#
# ### Topics
#
# - Effective Programming
#
# ### Effective Programming
#
# a) What is a drawback of the top down approach?

# %% [markdown]
# Sometimes it is not possible to decompose out code to smaller parts.

# %% [markdown]
# b) What is a drawback of the bottom up approach?

# %% [markdown]
# It is difficult to link how we merge smaller functions to get our system working, at the initial stages and we may end up writing redundant functions which we might not use in the code at all.

# %% [markdown]
# c) What are 3 things you can do to have a better debugging experience?

# %% [markdown]
# go through the error, and reread the code. sanity check to check how things are communicating to each other. Go online, or take the help of auto-programming tools. (copilot, ChatGPT etc.) and Take necessary breaks, before I rethink my entire logic.

# %% [markdown]
# d) Follow along with the live coding. You can write your code here:

# %%
######## FOR SINGLE SOLUTION ##########

# %%
class Board:

    def __init__(self,n):

        self.n = n

        self.board = [["_" for _ in range(self.n)] for _ in range(self.n)]

    def __repr__(self):

        res = ""

        for row in self.board:
            for col in row:
                res += col
                res += " "
            res += "\n"

        return res

    def is_legal(self, row, col):

        # return True

        flag = ('Q' not in [self.board[i][col] for i in range(row)]) & ('Q' not in [self.board[row][i] for i in range(col)])


        flag = flag & ('Q' not in [self.board[row-i][col-i] for i in range(1, min(row+1, col+1))])
        flag = flag & ('Q' not in [self.board[row-i][col+i] for i in range(1, min(row+1, self.n-col))])

        
        return flag

    def set_queen_at(self, row, col):
        self.board[row][col] = "Q"

    def unset_queen_on(self, row):
        self.board[row] = ['_' for _ in range(self.n)]

    def get_queen_on(self, row):
        for col in range(self.n):
            if self.board[row][col] == 'Q':
                return col
        raise ValueError("programming error")

    def search(self):

        row = 0
        col = 0

        while row < self.n:

            if self.is_legal(row, col):
                self.set_queen_at(row, col)
                row += 1
                col = 0
            else:
                col += 1
                while col >= self.n:
                    col = self.get_queen_on(row - 1)
                    self.unset_queen_on(row - 1)
                    col += 1
                    row -= 1 

        print("found a solution\n")
        print(self)
                        

myBoard = Board(n=5)
myBoard.search()
# Out:
# found a solution
#
# Q _ _ _ _
# _ _ Q _ _
# _ _ _ _ Q
# _ Q _ _ _
# _ _ _ Q _

# %%
##### FOR ALL SOLUTIONS ##################

# %%
class Board:

    def __init__(self, n):

        self.n = n

        self.board = [["_" for _ in range(n)] for _ in range(n)]

    def __repr__(self):

        res = ""

        for row in self.board:
            for col in row:
                res += col
                res += " "
            res += "\n"
            
        return res

    def is_legal(self, row, col):

        if col >= self.n or row >= self.n:
            return False

        flag = ('Q' not in [self.board[i][col] for i in range(row)]) & ('Q' not in [self.board[row][i] for i in range(col)])


        flag = flag & ('Q' not in [self.board[row-i][col-i] for i in range(1, min(row+1, col+1))])
        flag = flag & ('Q' not in [self.board[row-i][col+i] for i in range(1, min(row+1, self.n-col))])
        
        return flag

    def set_queen_at(self, row, col):
        self.board[row][col] = "Q"

    def unset_queen_on(self, row):
        self.board[row] = ['_' for _ in range(self.n)]

    def get_queen_on(self, row):
        for col in range(self.n):
            if self.board[row][col] == 'Q':
                return col

        if row == -1:
            raise ValueError(f"Solutions all found\n ")
        else:
            raise ValueError(f"Programming error at row = {row}")

    def search(self):

        row = 0
        col = 0

        cnt = 0

        while row >= 0:

            if row < self.n:
    
                if self.is_legal(row, col):
                    self.set_queen_at(row, col)
                    row += 1
                    col = 0
                else:
                    col += 1

                    while col >= self.n:
                            
                        col = self.get_queen_on(row - 1)
                        self.unset_queen_on(row - 1)
                        col += 1
                        row -= 1 

            else:

                cnt += 1

                print("found a solution\n")
                print(f"solution number : {cnt}\n")

                print(self)
                    
                col = self.get_queen_on(row - 1)
                self.unset_queen_on(row - 1)
                col += 1
                row -= 1 

      
                    
myBoard = Board(10)
myBoard.search()
# Out:
# found a solution
#
# solution number : 1
#
# Q _ _ _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _ _ _
# _ _ _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _ _ _
#
# found a solution
#
# solution number : 2
#
# Q _ _ _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _ _ _
# _ _ _ _ _ _ _ _ Q _
# _ _ _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ _ _ Q
# _ _ _ Q _ _ _ _ _ _
# _ Q _ _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ Q _ _
#
# found a solution
#
# solution number : 3
#
# Q _ _ _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _ _ _
# _ _ _ _ _ _ _ _ Q _
# _ _ _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ _ _ Q
# _ _ _ Q _ _ _ _ _ _
# _ Q _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ Q _ _
# _ _ _ _ Q _ _ _ _ _
#
# found a solution
#
# solution number : 4
#
# Q _ _ _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ Q _
# _ _ _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ _ _ Q
# _ _ _ Q _ _ _ _ _ _
# _ Q _ _ _ _ _ _ _ _
# ...
